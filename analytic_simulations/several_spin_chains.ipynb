# %%
# import modules
from qutip import *
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from functools import reduce
import importlib
import time
import os
import sys

# locate directory containing scripts 
current_directory = os.getcwd() 
src_directory = os.path.dirname(current_directory) + '/src'
sys.path.append(src_directory)

# import custom module
import spin_chain, simulate_algorithm
importlib.reload(spin_chain)
importlib.reload(simulate_algorithm);

# %% [markdown]
# ## $\hat{H}_2 = X_1 X_2 + Y_1 Y_2 + \lambda Z_1 Z_2 $

# %%
# specify parameters of 2-site spin chain
N2 = 2
Jx = 1
Jy = 1
Jz = 1
periodic_bc = False
tolerance = 1e-12

# calculate spin chain quantities
# calculate spin chain quantities
H2, H2_list, eigenstates2, eigenvalues2, E0_2, ρ_ground_state2 = \
    spin_chain.properties(N2, Jx, Jy, Jz, periodic_bc, tolerance)

# %%
N_cavities = 3
N_qubits = 3
m_start = 2
m_stop = 2
α_start = 0
α_end = 1
α_steps = 100
Es = E0_2
num_states = 5
cutoff = 'N/A'
save_file = True

Ψ0_list, ψ0_list  = simulate_algorithm.generate_initial_states(N_cavities, N_qubits, num_states, cutoff)
fidelity_array_list = simulate_algorithm.plot_exact_fidelity( \
                        N_cavities, α_start, α_end, α_steps, Es, m_start, m_stop, \
                        N_qubits, Jx, Jy, Jz, periodic_bc, tolerance, ψ0_list, save_file)

# %%
N_cavities = 2
N_qubits = 2
m_start = 1
m_stop = 2
α_start = 0
α_end = 1
α_steps = 100
Es = E0_2
num_states = 4
cutoff = 'N/A'
save_file = True

Ψ0_list, ψ0_list  = simulate_algorithm.generate_initial_states(N_cavities, N_qubits, num_states, cutoff)
fidelity_array_list = simulate_algorithm.plot_exact_fidelity( \
                        N_cavities, α_start, α_end, α_steps, Es, m_start, m_stop, \
                        N_qubits, Jx, Jy, Jz, periodic_bc, tolerance, ψ0_list, save_file)

# %% [markdown]
# # $\hat{H}_4 = \sum_{j = 1}^{4} X_j X_{j+1} + Y_j Y_{j+1} + \lambda Z_j Z_{j+1} $

# %%
# specify parameters of 2-site spin chain
N4 = 4
Jx = 1
Jy = 1
Jz = 1
periodic_bc = True
tolerance = 1e-9

# calculate spin chain quantities
H4, H4_list, eigenstates4, eigenvalues4, E0_4, ρ_ground_state4 = \
    spin_chain.properties(N4, Jx, Jy, Jz, periodic_bc, tolerance)

# %%
N_cavities = 4
N_qubits = 4
m_start = 4
m_stop = 4
α_start = 0
α_end = 1
α_steps = 100
Es = E0_4
num_states = 5
cutoff = 'N/A'
save_file = True

Ψ0_list, ψ0_list  = simulate_algorithm.generate_initial_states(N_cavities, N_qubits, num_states, cutoff)
fidelity_array_list = simulate_algorithm.plot_exact_fidelity( \
                        N_cavities, α_start, α_end, α_steps, Es, m_start, m_stop, \
                        N_qubits, Jx, Jy, Jz, periodic_bc, tolerance, ψ0_list, save_file)

# %%
N_cavities = 4
N_qubits = 4
m_start = 1
m_stop = 4
α_start = 0
α_end = 1
α_steps = 100
Es = E0_4
num_states = 1
cutoff = 'N/A'
save_file = True

Ψ0_list, ψ0_list  = simulate_algorithm.generate_initial_states(N_cavities, N_qubits, num_states, cutoff)
fidelity_array_list = simulate_algorithm.plot_exact_fidelity( \
                        N_cavities, α_start, α_end, α_steps, Es, m_start, m_stop, \
                        N_qubits, Jx, Jy, Jz, periodic_bc, tolerance, ψ0_list, save_file)

# %% [markdown]
# # $\hat{H}_6 = \sum_{j = 1}^{6} X_j X_{j+1} + Y_j Y_{j+1} + \lambda Z_j Z_{j+1} $

# %%
# specify parameters of spin chain 
N6 = 6
Jx = 1
Jy = 1
Jz = 1
periodic_bc = True
tolerance6 = 1e-9

# calculate spin chain quantities
H6, H6_list, eigenstates6, eigenvalues6, E0_6, ρ_ground_state6 = \
    spin_chain.properties(N6, Jx, Jy, Jz, periodic_bc, tolerance)
spin_chain.orthonormal_eigenstates(eigenstates6, tolerance6)
# Out:
# Your eigenstates form an orthonormal basis!

# %%
N_cavities = 6
N_qubits = 6
m_start = 6
m_stop = 6
α_start = 0
α_end = 1
α_steps = 100
Es = E0_6
num_states = 5
cutoff = 'N/A'
save_file = True

Ψ0_list, ψ0_list  = simulate_algorithm.generate_initial_states(N_cavities, N_qubits, num_states, cutoff)
fidelity_array_list = simulate_algorithm.plot_exact_fidelity( \
                        N_cavities, α_start, α_end, α_steps, Es, m_start, m_stop, \
                        N_qubits, Jx, Jy, Jz, periodic_bc, tolerance, ψ0_list, save_file)

# %%
N_cavities = 6
N_qubits = 6
m_start = 1
m_stop = 6
α_start = 0
α_end = 1
α_steps = 100
Es = E0_6
num_states = 1
cutoff = 'N/A'
save_file = True

Ψ0_list, ψ0_list  = simulate_algorithm.generate_initial_states(N_cavities, N_qubits, num_states, cutoff)
fidelity_array_list = simulate_algorithm.plot_exact_fidelity( \
                        N_cavities, α_start, α_end, α_steps, Es, m_start, m_stop, \
                        N_qubits, Jx, Jy, Jz, periodic_bc, tolerance, ψ0_list, save_file)

# %% [markdown]
# # $\hat{H}_8 = \sum_{j = 1}^{8} X_j X_{j+1} + Y_j Y_{j+1} + \lambda Z_j Z_{j+1} $

# %%
# specify parameters of spin chain 
N8 = 8
Jx = 1
Jy = 1
Jz = 1
periodic_bc = True
tolerance8 = 1e-9

# calculate spin chain quantities
H8, H8_list, eigenstates8, eigenvalues8, E0_8, ρ_ground_state8 = \
    spin_chain.properties(N8, Jx, Jy, Jz, periodic_bc, tolerance)
spin_chain.orthonormal_eigenstates(eigenstates8, tolerance8)
# Out:
# Your eigenstates form an orthonormal basis!

# %%
N_cavities = 8
N_qubits = 8
m_start = 8
m_stop = 8
α_start = 0
α_end = 1
α_steps = 100
Es = E0_8
num_states = 5
cutoff = 'N/A'
save_file = True

Ψ0_list, ψ0_list  = simulate_algorithm.generate_initial_states(N_cavities, N_qubits, num_states, cutoff)
fidelity_array_list = simulate_algorithm.plot_exact_fidelity( \
                        N_cavities, α_start, α_end, α_steps, Es, m_start, m_stop, \
                        N_qubits, Jx, Jy, Jz, periodic_bc, tolerance, ψ0_list, save_file)

# %%
N_cavities = 8
N_qubits = 8
m_start = 1
m_stop = 8
α_start = 0
α_end = 1
α_steps = 100
Es = E0_8
num_states = 1
cutoff = 'N/A'
save_file = True

Ψ0_list, ψ0_list  = simulate_algorithm.generate_initial_states(N_cavities, N_qubits, num_states, cutoff)
fidelity_array_list = simulate_algorithm.plot_exact_fidelity( \
                        N_cavities, α_start, α_end, α_steps, Es, m_start, m_stop, \
                        N_qubits, Jx, Jy, Jz, periodic_bc, tolerance, ψ0_list, save_file)

# %% [markdown]
# # $\hat{H}_{10} = \sum_{j = 1}^{10} X_j X_{j+1} + Y_j Y_{j+1} + \lambda Z_j Z_{j+1} $

# %%
# specify parameters of spin chain 
N10 = 10
Jx = 1
Jy = 1
Jz = 1
periodic_bc = True
tolerance10 = 1e-9

# calculate spin chain quantities
H10, H10_list, eigenstates10, eigenvalues10, E0_10, ρ_ground_state10 = \
    spin_chain.properties(N10, Jx, Jy, Jz, periodic_bc, tolerance)
spin_chain.orthonormal_eigenstates(eigenstates10, tolerance10)
# Out:
# Your eigenstates form an orthonormal basis!

# %%
N_cavities = 10
N_qubits = 10
m_start = 10
m_stop = 10
α_start = 0
α_end = 1
α_steps = 100
Es = E0_10
num_states = 5
cutoff = 'N/A'
save_file = True

Ψ0_list, ψ0_list  = simulate_algorithm.generate_initial_states(N_cavities, N_qubits, num_states, cutoff)
fidelity_array_list = simulate_algorithm.plot_exact_fidelity( \
                        N_cavities, α_start, α_end, α_steps, Es, m_start, m_stop, \
                        N_qubits, Jx, Jy, Jz, periodic_bc, tolerance, ψ0_list, save_file)

# %%
N_cavities = 10
N_qubits = 10
m_start = 1
m_stop = 10
α_start = 0
α_end = 1
α_steps = 100
Es = E0_10
num_states = 1
cutoff = 'N/A'
save_file = True

Ψ0_list, ψ0_list  = simulate_algorithm.generate_initial_states(N_cavities, N_qubits, num_states, cutoff)
fidelity_array_list = simulate_algorithm.plot_exact_fidelity( \
                        N_cavities, α_start, α_end, α_steps, Es, m_start, m_stop, \
                        N_qubits, Jx, Jy, Jz, periodic_bc, tolerance, ψ0_list, save_file)
