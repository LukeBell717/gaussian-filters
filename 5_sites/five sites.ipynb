# %%
# import modules
from qutip import *
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import importlib

# import custom module
import spin_chain
importlib.reload(spin_chain)

# define identity for qubits 
I2 = qeye(2)

# define Pauli matrices and constants
σ_x = sigmax()
σ_y = sigmay()
σ_z = sigmaz()
π = np.pi

# font specs for plots
# %matplotlib inline
mpl.rcParams["font.family"] = "STIXGeneral"
mpl.rcParams["mathtext.fontset"] = "stix"
mpl.rcParams["font.size"] = "14"

# %%
N = 5
Jx = 1
Jy = 1
Jz = 1
tolerance5 = 1e-12
H5, eigenstates5, eigenvalues5, min_eigenvalue5, ρ_ground_state5 = spin_chain.quantities(N,Jx,Jy,Jz, tolerance5)
spin_chain.verify_orthonormality(eigenstates5, tolerance5)
# Out:
# When N = 5 your eigenstates form an orthonormal basis!

# %%
N_qubits = 5
N_cavities = 5
m_start = 5
m_stop = 5
α_start = 0
α_end = 0.6
α_steps = 75
λ = 1
E_n = min_eigenvalue5
r = 1
num_states = 4
cutoff = 9
save_file = True

initial_state_list = spin_chain.generate_initial_states(N_cavities, N_qubits, num_states, cutoff)
spin_chain.plot_fidelity(N_cavities, N_qubits, eigenvalues5, eigenstates5, m_start, m_stop, α_start, α_end, α_steps, \
                  initial_state_list, cutoff, save_file);

# %%
N = 5
num_states = 5
n_start = 5
n_stop = 5
α_start = 0
α_end = 1
α_steps = 100
cutoff = 9

initial_state_list = spin_chain.generate_initial_states(num_states, N, cutoff)
spin_chain.plot_fidelity(initial_state_list, N, n_start, n_stop, eigenvalues5, eigenstates5, \
                         α_start, α_end, α_steps, cutoff)

# %%
N = 6
tolerance6 = 1e-12
H6, eigenstates6, eigenvalues6, min_eigenvalue6, ρ_ground_state6 = spin_chain.quantities(N,Jx,Jy,Jz, tolerance6)
spin_chain.verify_orthonormality(eigenstates6, tolerance6)
# Out:
# When N = 6 your eigenstates form an orthonormal basis!

# %%
N_qubits = 6
N_cavities = 6
m_start = 6
m_stop = 6
α_start = 0
α_end = 1
α_steps = 100
λ = 1
E_n = min_eigenvalue6
r = 1
num_states = 4
cutoff = 9
save_file = True

initial_state_list = spin_chain.generate_initial_states(N_cavities, N_qubits, num_states, cutoff)
spin_chain.plot_fidelity(N_cavities, N_qubits, eigenvalues6, eigenstates6, m_start, m_stop, \
                         α_start, α_end, α_steps, initial_state_list, cutoff, save_file);

# %%
N = 6
num_states = 1
n_start = 1
n_stop = 6
initial_state_list = spin_chain.generate_initial_states(num_states, N, cutoff)
spin_chain.plot_fidelity(initial_state_list, N, n_start, n_stop, eigenvalues6, eigenstates6, \
                         α_start, α_end, α_steps, cutoff)

# %%
N = 6
num_states = 5
n_start = 6
n_stop = 6
initial_state_list = spin_chain.generate_initial_states(num_states, N, cutoff)
spin_chain.plot_fidelity(initial_state_list, N, n_start, n_stop, eigenvalues6, eigenstates6, \
                         α_start, α_end, α_steps, cutoff)

# %%
N = 7
tolerance7 = 1e-12
H7, eigenstates7, eigenvalues7, min_eigenvalue7, ρ_ground_state7 = spin_chain.quantities(N,Jx,Jy,Jz, tolerance7)
spin_chain.verify_orthonormality(eigenstates7, tolerance7)
# Out:
# When N = 7 your eigenstates are not orthonormal

# %%
N = 7
num_states = 1
n_start = 1
n_stop = 7
initial_state_list = spin_chain.generate_initial_states(num_states, N, cutoff)
spin_chain.plot_fidelity(initial_state_list, N, n_start, n_stop, eigenvalues7, eigenstates7, \
                         α_start, α_end, α_steps, cutoff)

# %%
N = 7
num_states = 5
n_start = 7
n_stop = 7
initial_state_list = spin_chain.generate_initial_states(num_states, N, cutoff)
spin_chain.plot_fidelity(initial_state_list, N, n_start, n_stop, eigenvalues7, eigenstates7, \
                         α_start, α_end, α_steps, cutoff)

# %%
N = 8
tolerance8 = 1e-12
H8, eigenstates8, eigenvalues8, min_eigenvalue8, ρ_ground_state8 = spin_chain.quantities(N,Jx,Jy,Jz)
spin_chain.verify_orthonormality(eigenstates8, tolerance8)
# Out:
# When N = 8 your eigenstates are not orthonormal

# %%
N = 9
tolerance9 = 1e-12
H9, eigenstates9, eigenvalues9, min_eigenvalue9, ρ_ground_state9 = spin_chain.quantities(N,Jx,Jy,Jz)
spin_chain.verify_orthonormality(eigenstates9, tolerance9)
# Out:
# When N = 9 your eigenstates are not orthonormal

# %%
N = 10
tolerance10 = 1e-12
H10, eigenstates10, eigenvalues10, min_eigenvalue10, ρ_ground_state10 = spin_chain.quantities(N,Jx,Jy,Jz)
spin_chain.verify_orthonormality(eigenstates10, tolerance10)
# Out:
# When N = 10 your eigenstates are not orthonormal
